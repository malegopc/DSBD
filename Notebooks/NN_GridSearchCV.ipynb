# %% [markdown]
# ---
#
#
#
# ---
# # Otimização de hiperparâmetros utilizando a classe GridSearchCV do scikit-learn
#
# Este notebook mostra:
#
#
# * Como usar modelos Keras no scikit-learn empregando a classe [KerasClassifier](https://www.tensorflow.org/api_docs/python/tf/keras/wrappers/scikit_learn/KerasClassifier) (ou [KerasRegressor](https://www.tensorflow.org/api_docs/python/tf/keras/wrappers/scikit_learn/KerasRegressor) para tarefas de regressão)
# * Como otimizar hiperparâmetros de um modelo de aprendizado profundo utilizando Keras e a classe [GridSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) (*cross-validated grid-search*) do scikit-learn.
#
# O notebook foi aplicado na tarefa de classifcação do conjunto de dados de [predição política](https://https://github.com/malegopc/AM2PUCPOC/tree/main/Datasets/Predicao_Politica).
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Classes específicas
#
# A classe KerasClassifier (ou KerasRegressor) permitem a utilização de modelos Keras em scikit-learn por meio do encapsulamento dos modelos.
#
# A classe GridSearch realiza um pesquisa (combinação) exaustiva de valores de hiperparâmetros para um modelo. Os hiperparâmetros do modelo são otimizados por validação cruzada sobre uma grade (*grid*) de parâmetros fornecida.

# %%
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %% [markdown]
# ## Leitura dos dados

# %%
import pandas as pd

# Clone do repositório de dados do GitHub
# !git clone https://github.com/malegopc/DSBD
# cria vetor com os rótulos de cada atributo
nomes_atributos = ['Partido', 'Crianças deficientes', 'Compartilhamento de custos do projeto de água',
                    'Resolução de adoção do orçamento', 'Congelamento de honorários médicos',
                    'Ajuda El Salvador', 'Grupos religiosos nas escolas',
                    'Proibição de teste anti-satélite', 'Ajuda a contras nicaraguenses',
                    'Míssil MX', 'Imigração', 'Corte de corporação de combustíveis Syn',
                    'Gastos com educação', ' Super fundo direto', 'Crime',
                    'Exportações isentas de impostos', 'Exportação África do Sul']

# lê arquivo de dados, atribue NaN para dados faltantes e rótulos em cada coluna
dados_votacao = pd.read_csv('/content/DSBD/Datasets/Predicao_Politica/votes_data.txt', na_values=['?'], names = nomes_atributos)
# imprime as 5 primeiras linha dos dados montados
dados_votacao.head()
# Out:
# Cloning into 'DSBD'...
# remote: Enumerating objects: 549, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 549 (delta 39), reused 71 (delta 28), pack-reused 457
# Receiving objects: 100% (549/549), 10.07 MiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (247/247), done.
#       Partido Crianças deficientes  \
# 0  republican                    n
# 1  republican                    n
# 2    democrat                  NaN
# 3    democrat                    n
# 4    democrat                    y
#
#   Compartilhamento de custos do projeto de água  \
# 0                                             y
# 1                                             y
# 2                                             y
# 3                                             y
# 4                                             y
#
#   Resolução de adoção do orçamento Congelamento de honorários médicos  \
# 0                                n                                  y
# 1                                n                                  y
# 2                                y                                NaN
# 3                                y                                  n
# 4                                y                                  n
#
#   Ajuda El Salvador Grupos religiosos nas escolas  \
# 0                 y                             y
# 1                 y                             y
# 2                 y                             y
# 3               NaN                             y
# 4                 y                             y
#
#   Proibição de teste anti-satélite Ajuda a contras nicaraguenses Míssil MX  \
# 0                                n                             n         n
# 1                                n                             n         n
# 2                                n                             n         n
# 3                                n                             n         n
# 4                                n                             n         n
#
#   Imigração Corte de corporação de combustíveis Syn Gastos com educação  \
# 0         y                                     NaN                   y
# 1         n                                       n                   y
# 2         n                                       y                   n
# 3         n                                       y                   n
# 4         n                                       y                 NaN
#
#    Super fundo direto Crime Exportações isentas de impostos  \
# 0                   y     y                               n
# 1                   y     y                               n
# 2                   y     y                               n
# 3                   y     n                               n
# 4                   y     y                               y
#
#   Exportação África do Sul
# 0                        y
# 1                      NaN
# 2                        n
# 3                        y
# 4                        y

# %% [markdown]
# ## Eliminação de dados ausentes

# %%
# Remove dados faltantes na própria variável 
dados_votacao.dropna(inplace=True)
dados_votacao.describe()
# Out:
#          Partido  ... Exportação África do Sul
# count        232  ...                      232
# unique         2  ...                        2
# top     democrat  ...                        y
# freq         124  ...                      189
#
# [4 rows x 17 columns]

# %% [markdown]
# ## Codificação de dados categóricos

# %%
dados_votacao.replace(('y', 'n'), (1, 0), inplace=True)
dados_votacao.replace(('democrat', 'republican'), (1, 0), inplace=True)
dados_votacao.head()
# Out:
#     Partido  ...  Exportação África do Sul
# 5         1  ...                         1
# 8         0  ...                         1
# 19        1  ...                         1
# 23        1  ...                         1
# 25        1  ...                         1
#
# [5 rows x 17 columns]

# %% [markdown]
# ## Separa os atributos (recursos) e a variável target (alvo)

# %%
X = dados_votacao[nomes_atributos].drop('Partido', axis=1).values
y = dados_votacao['Partido'].values
print(X.shape)
print(y.shape)
# Out:
# (232, 16)
# (232,)

# %% [markdown]
# ## Número de nerônios das camadas ocultas
#
# Busca os melhores números de neurônios das duas camadas ocultas.

# %%
# função que cria o modelo Keras
def cria_model(units1, units2):
  # cria modelo	
  model = Sequential()
  model.add(Dense(units=units1, kernel_initializer = 'he_uniform', activation='relu',input_dim=16))
  model.add(Dense(units=units2, kernel_initializer = 'he_uniform', activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  # Compila o modelo
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model
# cria e encapsula o modelo por meio do Keras_Classifier
model = KerasClassifier(build_fn=cria_model, verbose=0)
# busca os melhores parâmetros para batch_size e epochs
units1 = [8, 16, 32, 64]
units2 = [4, 8, 16, 32]
param_grid = dict(units1=units1, units2=units2)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_results = grid.fit(X, y)
# Melhor resultado (melhores parâmetros)
print("Melhor resultado: %f utilizando os parâmetros %s" % (grid_results.best_score_, grid_results.best_params_))
# Análise dos resultados dos testes
medias = grid_results.cv_results_['mean_test_score']
desvios = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for media, desvio, param in zip(medias, desvios, params):
    print("%f (%f) utilizando: %r" % (media, desvio, param))
# Out:
# Melhor resultado: 0.801976 utilizando os parâmetros {'units1': 32, 'units2': 16}
# 0.585137 (0.176221) utilizando: {'units1': 8, 'units2': 4}
# 0.421967 (0.142283) utilizando: {'units1': 8, 'units2': 8}
# 0.448551 (0.248043) utilizando: {'units1': 8, 'units2': 16}
# 0.404762 (0.121173) utilizando: {'units1': 8, 'units2': 32}
# 0.539294 (0.082178) utilizando: {'units1': 16, 'units2': 4}
# 0.573815 (0.200799) utilizando: {'units1': 16, 'units2': 8}
# 0.555056 (0.166020) utilizando: {'units1': 16, 'units2': 16}
# 0.634033 (0.158302) utilizando: {'units1': 16, 'units2': 32}
# 0.603730 (0.165618) utilizando: {'units1': 32, 'units2': 4}
# 0.430847 (0.167215) utilizando: {'units1': 32, 'units2': 8}
# 0.801976 (0.067198) utilizando: {'units1': 32, 'units2': 16}
# 0.589966 (0.102307) utilizando: {'units1': 32, 'units2': 32}
# 0.602842 (0.112766) utilizando: {'units1': 64, 'units2': 4}
# 0.534299 (0.030603) utilizando: {'units1': 64, 'units2': 8}
# 0.766733 (0.091244) utilizando: {'units1': 64, 'units2': 16}
# 0.491009 (0.071190) utilizando: {'units1': 64, 'units2': 32}

# %% [markdown]
# ## Tamanho do lote (batch_size) e número de épocas (epochs)
#
# Busca os melhores valores para batch_size e número de épocas.

# %%
# função que cria o modelo Keras
def cria_model():
  # cria modelo	
  model = Sequential()
  model.add(Dense(units=32, kernel_initializer = 'he_uniform', activation='relu',input_dim=16))
  model.add(Dense(units=16, kernel_initializer = 'he_uniform', activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  # Compila o modelo
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
  return model
# cria e encapsula o modelo por meio do Keras_Classifier
model = KerasClassifier(build_fn=cria_model, verbose=0)
# busca os melhores parâmetros para batch_size e epochs
batch_size = [4, 8, 16, 32]
epochs = [10, 50, 100]
param_grid = dict(batch_size=batch_size, epochs=epochs)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_results = grid.fit(X, y)
# Melhor resultado (melhores parâmetros)
print("Melhor resultado: %f utilizando os parâmetros %s" % (grid_results.best_score_, grid_results.best_params_))
# Análise dos resultados dos testes
medias = grid_results.cv_results_['mean_test_score']
desvios = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for media, desvio, param in zip(medias, desvios, params):
    print("%f (%f) utilizando: %r" % (media, desvio, param))
# Out:
# Melhor resultado: 0.961205 utilizando os parâmetros {'batch_size': 4, 'epochs': 50}
# 0.948274 (0.021210) utilizando: {'batch_size': 4, 'epochs': 10}
# 0.961205 (0.000235) utilizando: {'batch_size': 4, 'epochs': 50}
# 0.956876 (0.006243) utilizando: {'batch_size': 4, 'epochs': 100}
# 0.948274 (0.000314) utilizando: {'batch_size': 8, 'epochs': 10}
# 0.956821 (0.012401) utilizando: {'batch_size': 8, 'epochs': 50}
# 0.956876 (0.006243) utilizando: {'batch_size': 8, 'epochs': 100}
# 0.896492 (0.018647) utilizando: {'batch_size': 16, 'epochs': 10}
# 0.961150 (0.010740) utilizando: {'batch_size': 16, 'epochs': 50}
# 0.952547 (0.006358) utilizando: {'batch_size': 16, 'epochs': 100}
# 0.849095 (0.012698) utilizando: {'batch_size': 32, 'epochs': 10}
# 0.939560 (0.016420) utilizando: {'batch_size': 32, 'epochs': 50}
# 0.943834 (0.022226) utilizando: {'batch_size': 32, 'epochs': 100}

# %% [markdown]
# ## Otimizador
#
# Busca o melhor otimizador para treinar a rede.

# %%
# função que cria o modelo Keras
def cria_model(optimizer):
  # cria modelo	
  model = Sequential()
  model.add(Dense(units=32, kernel_initializer = 'he_uniform', activation='relu',input_dim=16))
  model.add(Dense(units=16, kernel_initializer = 'he_uniform', activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  # Compila o modelo
  model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  return model
# cria e encapsula o modelo por meio do Keras_Classifier
model = KerasClassifier(build_fn=cria_model, verbose=0)
# busca os melhores parâmetros para o otimizador
optimizer = ['SGD','RMSprop','Adam','Adadelta','Adagrad','Adamax','Nadam']
param_grid = dict(optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_results = grid.fit(X, y)
# Melhor resultado (melhores parâmetros)
print("Melhor resultado: %f utilizando os parâmetros %s" % (grid_results.best_score_, grid_results.best_params_))
# Análise dos resultados dos testes
medias = grid_results.cv_results_['mean_test_score']
desvios = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for media, desvio, param in zip(medias, desvios, params):
    print("%f (%f) utilizando: %r" % (media, desvio, param))
# Out:
# Melhor resultado: 0.740759 utilizando os parâmetros {'optimizer': 'RMSprop'}
# 0.560051 (0.075656) utilizando: {'optimizer': 'SGD'}
# 0.740759 (0.135909) utilizando: {'optimizer': 'RMSprop'}
# 0.370352 (0.105804) utilizando: {'optimizer': 'Adam'}
# 0.396825 (0.044896) utilizando: {'optimizer': 'Adadelta'}
# 0.638695 (0.125268) utilizando: {'optimizer': 'Adagrad'}
# 0.646243 (0.054960) utilizando: {'optimizer': 'Adamax'}
# 0.581585 (0.066407) utilizando: {'optimizer': 'Nadam'}

# %% [markdown]
# ## Número de neurônios, batch_size, épocas e otimizador
#
# *Obs: aproximadamente 3 horas na GPU do Colab*.

# %%
# função que cria o modelo Keras
def cria_model(units1, units2, optimizer):
  # cria modelo	
  model = Sequential()
  model.add(Dense(units=units1, kernel_initializer = 'he_uniform', activation='relu',input_dim=16))
  model.add(Dense(units=units2, kernel_initializer = 'he_uniform', activation='relu'))
  model.add(Dense(units=1, activation='sigmoid'))
  # Compila o modelo
  model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
  return model
# cria e encapsula o modelo por meio do Keras_Classifier
model = KerasClassifier(build_fn=cria_model, verbose=0)
# busca os melhores parâmetros para número de neurônios, batch_size, épocas e otimizador
units1 = [8, 16, 32, 64]
units2 = [4, 8, 16, 32]
batch_size = [4, 8, 16, 32]
epochs = [10, 50, 100]
optimizer = ['SGD','RMSprop','Adam','Adadelta','Adagrad','Adamax','Nadam']
param_grid = dict(units1=units1, units2=units2, batch_size=batch_size, epochs=epochs, optimizer=optimizer)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_results = grid.fit(X, y)
# Melhor resultado (melhores parâmetros)
print("Melhor resultado: %f utilizando os parâmetros %s" % (grid_results.best_score_, grid_results.best_params_))
# Análise dos resultados dos testes
medias = grid_results.cv_results_['mean_test_score']
desvios = grid_results.cv_results_['std_test_score']
params = grid_results.cv_results_['params']
for media, desvio, param in zip(medias, desvios, params):
    print("%f (%f) utilizando: %r" % (media, desvio, param))
# Out:
# Melhor resultado: 0.974081 utilizando os parâmetros {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.861916 (0.025116) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 4}
# 0.887890 (0.022256) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 8}
# 0.922300 (0.018680) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 16}
# 0.913697 (0.022348) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 32}
# 0.796981 (0.169371) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 4}
# 0.922411 (0.010614) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 8}
# 0.913864 (0.015728) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 16}
# 0.896437 (0.018837) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.896437 (0.028366) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 4}
# 0.939616 (0.006436) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 8}
# 0.887945 (0.016079) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 16}
# 0.909313 (0.028364) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 32}
# 0.913753 (0.032488) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 4}
# 0.930902 (0.022302) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 8}
# 0.943889 (0.016376) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 16}
# 0.926740 (0.005901) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 32}
# 0.900710 (0.024881) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 4}
# 0.892274 (0.011907) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 8}
# 0.913864 (0.015728) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 16}
# 0.926684 (0.006515) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 32}
# 0.922300 (0.021480) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 4}
# 0.922355 (0.010945) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 8}
# 0.900877 (0.016091) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 16}
# 0.918026 (0.012637) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 32}
# 0.913753 (0.006593) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 4}
# 0.935287 (0.018525) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 8}
# 0.935342 (0.010611) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 16}
# 0.935342 (0.010611) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 32}
# 0.931069 (0.012016) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 4}
# 0.943945 (0.006285) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 8}
# 0.935342 (0.010611) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 16}
# 0.948163 (0.021344) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 32}
# 0.870740 (0.009866) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 4}
# 0.905095 (0.016557) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 8}
# 0.905039 (0.027002) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 16}
# 0.913697 (0.022348) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 32}
# 0.896437 (0.018837) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 4}
# 0.926684 (0.006515) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 8}
# 0.939616 (0.012404) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 16}
# 0.905150 (0.006415) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 32}
# 0.948274 (0.021210) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 4}
# 0.926795 (0.015786) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 8}
# 0.935342 (0.010611) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 16}
# 0.939560 (0.016420) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 32}
# 0.939616 (0.012404) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 4}
# 0.948274 (0.000314) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 8}
# 0.952492 (0.016346) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 16}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 32}
# 0.448107 (0.050620) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 4}
# 0.551782 (0.064316) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 8}
# 0.568265 (0.139745) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 16}
# 0.547453 (0.153887) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 32}
# 0.400932 (0.012698) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 4}
# 0.426629 (0.159823) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 8}
# 0.539128 (0.193508) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 16}
# 0.576979 (0.153433) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 32}
# 0.435398 (0.127544) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 4}
# 0.326729 (0.145466) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 8}
# 0.461094 (0.032295) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 16}
# 0.645799 (0.127572) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 32}
# 0.552170 (0.074861) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 4}
# 0.509102 (0.083291) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 8}
# 0.496503 (0.133615) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 16}
# 0.483960 (0.214639) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 32}
# 0.551782 (0.106456) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 4}
# 0.547619 (0.046322) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 8}
# 0.634033 (0.067787) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 16}
# 0.723277 (0.150901) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 32}
# 0.564491 (0.059463) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 4}
# 0.654901 (0.045825) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 8}
# 0.702353 (0.083491) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 16}
# 0.887779 (0.027119) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 32}
# 0.698191 (0.065139) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 4}
# 0.818792 (0.114909) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 8}
# 0.711400 (0.115746) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 16}
# 0.857698 (0.028322) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 32}
# 0.698302 (0.021627) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 4}
# 0.832001 (0.027299) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 8}
# 0.818681 (0.083212) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 16}
# 0.874792 (0.050429) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.746531 (0.152017) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.913697 (0.050233) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.836330 (0.025750) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.849262 (0.061763) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.836330 (0.033359) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.866245 (0.034485) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.905206 (0.011943) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.900655 (0.034397) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.918082 (0.016293) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.892219 (0.016328) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.888056 (0.021237) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.900766 (0.016643) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.862082 (0.026601) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.922522 (0.017738) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.935287 (0.018525) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.917971 (0.026939) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.922355 (0.028186) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.887890 (0.006750) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.948274 (0.010609) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.930958 (0.016436) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.848818 (0.086648) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.939671 (0.005936) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.935342 (0.021211) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.930902 (0.026875) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.948274 (0.010609) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.931069 (0.012016) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 16}
# 0.922466 (0.018098) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 32}
# 0.918026 (0.024687) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 64, 'units2': 4}
# 0.948218 (0.010808) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 64, 'units2': 8}
# 0.948218 (0.010808) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 64, 'units2': 16}
# 0.969808 (0.016228) with: {'batch_size': 4, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 64, 'units2': 32}
# 0.943889 (0.016376) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 8, 'units2': 4}
# 0.965534 (0.006008) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 8, 'units2': 8}
# 0.943834 (0.022226) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 8, 'units2': 16}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 8, 'units2': 32}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 16, 'units2': 4}
# 0.935231 (0.021412) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 16, 'units2': 8}
# 0.965479 (0.022118) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 16, 'units2': 16}
# 0.974081 (0.010672) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.969808 (0.016228) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 32, 'units2': 4}
# 0.956821 (0.012401) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 32, 'units2': 8}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 32, 'units2': 16}
# 0.939616 (0.006436) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 32, 'units2': 32}
# 0.956821 (0.016317) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 64, 'units2': 4}
# 0.956932 (0.005808) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 64, 'units2': 8}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 64, 'units2': 16}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'SGD', 'units1': 64, 'units2': 32}
# 0.939505 (0.032514) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 4}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 8}
# 0.948163 (0.028158) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 16}
# 0.939616 (0.006436) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 32}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 4}
# 0.961094 (0.021276) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 8}
# 0.956765 (0.022150) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 16}
# 0.965534 (0.006008) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 32}
# 0.943889 (0.024607) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 4}
# 0.965479 (0.012324) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 8}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 16}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 32}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 4}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 8}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 16}
# 0.956821 (0.016317) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 32}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 8, 'units2': 4}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 8, 'units2': 8}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 8, 'units2': 16}
# 0.965423 (0.022128) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 8, 'units2': 32}
# 0.969808 (0.016228) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 16, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 16, 'units2': 8}
# 0.956932 (0.012090) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 16, 'units2': 16}
# 0.965534 (0.016155) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 16, 'units2': 32}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 32, 'units2': 4}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 32, 'units2': 8}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 32, 'units2': 16}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 32, 'units2': 32}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 64, 'units2': 4}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 64, 'units2': 8}
# 0.956821 (0.016317) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 64, 'units2': 16}
# 0.956932 (0.012090) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adam', 'units1': 64, 'units2': 32}
# 0.487013 (0.117003) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 4}
# 0.391719 (0.132214) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 8}
# 0.526030 (0.069301) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 16}
# 0.595127 (0.076260) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 32}
# 0.349983 (0.141201) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 4}
# 0.504496 (0.167143) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 8}
# 0.419358 (0.211334) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 16}
# 0.664336 (0.122957) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 32}
# 0.667000 (0.181771) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 4}
# 0.591020 (0.151646) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 8}
# 0.555112 (0.176203) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 16}
# 0.499667 (0.087948) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 32}
# 0.529637 (0.090353) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 4}
# 0.573760 (0.105107) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 8}
# 0.547730 (0.108625) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 16}
# 0.560329 (0.031923) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 32}
# 0.484238 (0.281762) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 4}
# 0.857698 (0.011290) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 8}
# 0.857587 (0.028672) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 16}
# 0.840493 (0.016402) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 32}
# 0.690754 (0.194899) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 4}
# 0.766900 (0.070283) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 8}
# 0.835886 (0.058892) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 16}
# 0.892108 (0.027065) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 32}
# 0.831613 (0.059529) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 4}
# 0.848873 (0.085986) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 8}
# 0.887945 (0.016079) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 16}
# 0.844766 (0.069653) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 32}
# 0.866189 (0.032915) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 4}
# 0.879065 (0.043220) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 8}
# 0.909535 (0.027856) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 16}
# 0.905206 (0.005494) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.905317 (0.031806) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.917971 (0.026939) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.930902 (0.022302) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.904984 (0.037498) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.935231 (0.028210) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.939671 (0.016128) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.948218 (0.010808) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.935287 (0.018525) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.939616 (0.006436) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.948218 (0.018485) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.948163 (0.018523) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.952603 (0.005971) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.952492 (0.016346) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.956932 (0.012090) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.943945 (0.006285) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.952492 (0.022183) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.961205 (0.021209) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.948107 (0.038289) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 16}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 32}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 4}
# 0.952603 (0.005971) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 8}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 16}
# 0.965534 (0.006008) with: {'batch_size': 4, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 32}
# 0.961150 (0.018445) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 4}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 8}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 16}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 32}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 4}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 8}
# 0.952492 (0.016346) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 16}
# 0.961261 (0.010333) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.969808 (0.006202) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 4}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 16}
# 0.965423 (0.016272) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 32}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 8}
# 0.961094 (0.018445) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 16}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 32}
# 0.948218 (0.018485) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 4}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 8}
# 0.961261 (0.010333) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 16}
# 0.952547 (0.022140) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 32}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 4}
# 0.956932 (0.012090) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 8}
# 0.956821 (0.012401) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 16}
# 0.948218 (0.018485) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 32}
# 0.952603 (0.005971) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 4}
# 0.965534 (0.016155) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 16}
# 0.956821 (0.016317) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 32}
# 0.969752 (0.016257) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 4}
# 0.965534 (0.006008) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 8}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 16}
# 0.952603 (0.005971) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 32}
# 0.956932 (0.005808) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 4}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 8}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 16}
# 0.965534 (0.006008) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 32}
# 0.965479 (0.012324) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 4}
# 0.952492 (0.030689) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 8}
# 0.961261 (0.010333) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 16}
# 0.969863 (0.012128) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 32}
# 0.948163 (0.018523) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 4}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 8}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 16}
# 0.943945 (0.016260) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 32}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 4}
# 0.965423 (0.016272) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 8}
# 0.965479 (0.006279) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 16}
# 0.952603 (0.005971) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 32}
# 0.482850 (0.075741) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 4}
# 0.430514 (0.194691) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 8}
# 0.530470 (0.121542) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 16}
# 0.418914 (0.203323) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 32}
# 0.650294 (0.149283) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 4}
# 0.556000 (0.027122) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 8}
# 0.469752 (0.020121) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 16}
# 0.581863 (0.079724) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 32}
# 0.573760 (0.087603) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 4}
# 0.534466 (0.042509) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 8}
# 0.582307 (0.121130) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 16}
# 0.504163 (0.093339) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 32}
# 0.423465 (0.192247) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 4}
# 0.617050 (0.172223) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 8}
# 0.659341 (0.134582) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 16}
# 0.624098 (0.151333) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 32}
# 0.759407 (0.134267) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 4}
# 0.677267 (0.173132) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 8}
# 0.879343 (0.011871) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 16}
# 0.857809 (0.038018) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 32}
# 0.806249 (0.047476) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 4}
# 0.685204 (0.113723) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 8}
# 0.887779 (0.027119) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 16}
# 0.913753 (0.022209) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 32}
# 0.840271 (0.040768) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 4}
# 0.896659 (0.017582) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 8}
# 0.870629 (0.011221) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 16}
# 0.900932 (0.011538) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 32}
# 0.887779 (0.049214) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 4}
# 0.909368 (0.021548) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 8}
# 0.909479 (0.010618) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 16}
# 0.905317 (0.025967) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.943889 (0.012480) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.935453 (0.017817) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.939616 (0.006436) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.952547 (0.012364) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.930958 (0.016436) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.965479 (0.012324) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.948329 (0.018173) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.956876 (0.006243) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.956932 (0.012090) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.956821 (0.016317) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.930958 (0.034201) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.956987 (0.021803) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.965534 (0.016155) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.952547 (0.006358) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.956876 (0.016244) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.974081 (0.010672) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.961094 (0.018445) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# 0.961205 (0.010606) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 16}
# 0.965534 (0.016155) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 32}
# 0.961205 (0.000235) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 4}
# 0.935231 (0.036851) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 8}
# 0.961150 (0.010740) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 16}
# 0.956932 (0.005808) with: {'batch_size': 4, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 32}
# 0.740593 (0.188820) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 4}
# 0.862193 (0.025874) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 8}
# 0.879121 (0.044475) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 16}
# 0.922411 (0.010614) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 8, 'units2': 32}
# 0.870407 (0.092029) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 4}
# 0.892274 (0.011907) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 8}
# 0.922244 (0.028286) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 16}
# 0.918082 (0.006371) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.781219 (0.172391) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 4}
# 0.892163 (0.012794) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 8}
# 0.926573 (0.026902) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 16}
# 0.900710 (0.024881) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 32, 'units2': 32}
# 0.896548 (0.021217) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 4}
# 0.879620 (0.051136) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 8}
# 0.896270 (0.046455) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 16}
# 0.922355 (0.010945) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'SGD', 'units1': 64, 'units2': 32}
# 0.870518 (0.038631) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 4}
# 0.874903 (0.016792) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 8}
# 0.896381 (0.032152) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 16}
# 0.896437 (0.021617) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 32}
# 0.922244 (0.028286) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 4}
# 0.896437 (0.036971) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 8}
# 0.900655 (0.037524) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 16}
# 0.909368 (0.021548) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 32}
# 0.883561 (0.011152) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 4}
# 0.913864 (0.011616) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 8}
# 0.922244 (0.028286) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 16}
# 0.943889 (0.016376) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 32}
# 0.930958 (0.016436) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 4}
# 0.926629 (0.022293) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 8}
# 0.943889 (0.012480) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 16}
# 0.935342 (0.000392) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 32}
# 0.849428 (0.063788) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 4}
# 0.913808 (0.005867) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 8}
# 0.913697 (0.040297) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 16}
# 0.883505 (0.021685) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 8, 'units2': 32}
# 0.922411 (0.031815) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 4}
# 0.935231 (0.018602) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 8}
# 0.909313 (0.028364) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 16}
# 0.900877 (0.005834) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 16, 'units2': 32}
# 0.922411 (0.010614) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 4}
# 0.913808 (0.016103) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 8}
# 0.926629 (0.030769) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 16}
# 0.931013 (0.006327) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 32, 'units2': 32}
# 0.931013 (0.006327) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 4}
# 0.926629 (0.022293) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 8}
# 0.935453 (0.017817) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 16}
# 0.952603 (0.005971) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adam', 'units1': 64, 'units2': 32}
# 0.436286 (0.181503) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 4}
# 0.478521 (0.207124) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 8}
# 0.430958 (0.013632) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 16}
# 0.543235 (0.030204) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 32}
# 0.439560 (0.045173) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 4}
# 0.582085 (0.048259) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 8}
# 0.587024 (0.146196) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 16}
# 0.500056 (0.127572) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 32}
# 0.580753 (0.189530) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 4}
# 0.520868 (0.116585) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 8}
# 0.470585 (0.126045) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 16}
# 0.508769 (0.044378) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 32}
# 0.500444 (0.107843) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 4}
# 0.461261 (0.043333) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 8}
# 0.461427 (0.059885) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 16}
# 0.358586 (0.145697) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 32}
# 0.585248 (0.164370) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 4}
# 0.530137 (0.037577) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 8}
# 0.762349 (0.095668) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 16}
# 0.625042 (0.175097) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 32}
# 0.443556 (0.130001) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 4}
# 0.577034 (0.113819) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 8}
# 0.840493 (0.047885) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 16}
# 0.602897 (0.127670) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 32}
# 0.612221 (0.114104) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 4}
# 0.680764 (0.114968) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 8}
# 0.655789 (0.170946) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 16}
# 0.832057 (0.063974) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 32}
# 0.727717 (0.178805) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 4}
# 0.538295 (0.084414) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 8}
# 0.827450 (0.034636) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 16}
# 0.853369 (0.044371) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.742369 (0.170755) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.801365 (0.075778) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.883450 (0.028518) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.879620 (0.051136) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.784438 (0.043052) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.866467 (0.021431) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.883561 (0.011152) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.896437 (0.018837) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.909646 (0.031134) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.822899 (0.131989) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.892274 (0.005416) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.900655 (0.034397) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.835886 (0.086696) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.896603 (0.009998) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.909590 (0.017660) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.909535 (0.027856) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.862027 (0.012655) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.909313 (0.028364) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.909313 (0.032084) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.926684 (0.006515) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.879398 (0.021484) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.879121 (0.032841) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.909313 (0.028364) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.935287 (0.010877) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.892385 (0.023625) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.922411 (0.010614) with: {'batch_size': 8, 'epochs': 10, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# ...
# 0.866356 (0.037312) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.715063 (0.077522) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.904984 (0.032692) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.900877 (0.005834) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.827672 (0.030039) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.866356 (0.016364) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.896714 (0.027208) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.887890 (0.006750) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.909479 (0.010618) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.887668 (0.048097) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.918082 (0.006371) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.935287 (0.018525) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.939727 (0.011773) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.922355 (0.018566) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.917971 (0.026939) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.917971 (0.022379) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.948274 (0.021210) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.896659 (0.020532) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.905150 (0.016310) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.922355 (0.018566) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.930958 (0.016436) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.918248 (0.031865) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.931180 (0.023861) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.926629 (0.016495) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.939560 (0.016420) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.935231 (0.018602) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.935231 (0.021412) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# 0.935231 (0.021412) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 16}
# 0.935287 (0.010877) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 32, 'units2': 32}
# 0.922244 (0.046362) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 4}
# 0.956821 (0.016317) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 16}
# 0.961205 (0.010606) with: {'batch_size': 32, 'epochs': 50, 'optimizer': 'Nadam', 'units1': 64, 'units2': 32}
# 0.900821 (0.032504) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 4}
# 0.896548 (0.010622) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 8}
# 0.896603 (0.009998) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 16}
# 0.896381 (0.032152) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 8, 'units2': 32}
# 0.909368 (0.021548) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 4}
# 0.909479 (0.021215) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 8}
# 0.926740 (0.016115) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 16}
# 0.922466 (0.010132) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 16, 'units2': 32}
# 0.926684 (0.032472) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 4}
# 0.900766 (0.022403) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 8}
# 0.909535 (0.010065) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 16}
# 0.926740 (0.005901) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 32, 'units2': 32}
# 0.952436 (0.026758) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 4}
# 0.943889 (0.012480) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 8}
# 0.931013 (0.006327) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 16}
# 0.926740 (0.005901) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'SGD', 'units1': 64, 'units2': 32}
# 0.939505 (0.024646) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 4}
# 0.948329 (0.018173) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 8}
# 0.943889 (0.016376) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 16}
# 0.935287 (0.018525) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 8, 'units2': 32}
# 0.926518 (0.037381) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 4}
# 0.943945 (0.006285) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 8}
# 0.961150 (0.010740) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 16}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 16, 'units2': 32}
# 0.965479 (0.006279) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 8}
# 0.961205 (0.010606) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 16}
# 0.961205 (0.010606) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 32, 'units2': 32}
# 0.939560 (0.030729) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 4}
# 0.952547 (0.006358) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 8}
# 0.969752 (0.016257) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 16}
# 0.952603 (0.005971) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'RMSprop', 'units1': 64, 'units2': 32}
# 0.939560 (0.016420) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 4}
# 0.948163 (0.021344) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 8}
# 0.935231 (0.021412) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 16}
# 0.939560 (0.022238) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 8, 'units2': 32}
# 0.939560 (0.016420) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 8}
# 0.965590 (0.011930) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 16}
# 0.952492 (0.016346) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 16, 'units2': 32}
# 0.956821 (0.012401) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 4}
# 0.961205 (0.000235) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 16}
# 0.956765 (0.022150) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 32, 'units2': 32}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 4}
# 0.952547 (0.012364) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 8}
# 0.956932 (0.005808) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 16}
# 0.952492 (0.022183) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adam', 'units1': 64, 'units2': 32}
# 0.456821 (0.029267) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 4}
# 0.384338 (0.117655) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 8}
# 0.520868 (0.119913) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 16}
# 0.462204 (0.170464) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 8, 'units2': 32}
# 0.430902 (0.057274) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 4}
# 0.517483 (0.226167) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 8}
# 0.534410 (0.013055) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 16}
# 0.250527 (0.113978) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 16, 'units2': 32}
# 0.500222 (0.051998) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 4}
# 0.547397 (0.042504) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 8}
# 0.538739 (0.033025) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 16}
# 0.612388 (0.067317) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 32, 'units2': 32}
# 0.684593 (0.263868) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 4}
# 0.517039 (0.039462) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 8}
# 0.507881 (0.130389) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 16}
# 0.452214 (0.117759) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adadelta', 'units1': 64, 'units2': 32}
# 0.578089 (0.092688) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 4}
# 0.624820 (0.094866) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 8}
# 0.758186 (0.159911) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 16}
# 0.741203 (0.055778) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 8, 'units2': 32}
# 0.607226 (0.102189) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 4}
# 0.848929 (0.058766) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 8}
# 0.693251 (0.117184) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 16}
# 0.793318 (0.036727) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 16, 'units2': 32}
# 0.710845 (0.204972) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 4}
# 0.770951 (0.144731) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 8}
# 0.784105 (0.075126) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 16}
# 0.853313 (0.027256) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 32, 'units2': 32}
# 0.840437 (0.013108) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 4}
# 0.772505 (0.156787) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 8}
# 0.862138 (0.015498) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 16}
# 0.917915 (0.044311) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adagrad', 'units1': 64, 'units2': 32}
# 0.892108 (0.034385) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 4}
# 0.896492 (0.018647) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 8}
# 0.918082 (0.006371) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 16}
# 0.930958 (0.012558) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 8, 'units2': 32}
# 0.931013 (0.006327) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 4}
# 0.922300 (0.021480) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 8}
# 0.914030 (0.039290) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 16}
# 0.922411 (0.021213) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 16, 'units2': 32}
# 0.930902 (0.034235) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 4}
# 0.922466 (0.027880) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 8}
# 0.943889 (0.024607) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 16}
# 0.952492 (0.022183) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 32, 'units2': 32}
# 0.943889 (0.024607) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 4}
# 0.952547 (0.006358) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 8}
# 0.943834 (0.022226) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 16}
# 0.956876 (0.016244) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Adamax', 'units1': 64, 'units2': 32}
# 0.930958 (0.034201) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 4}
# 0.931013 (0.016276) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 8}
# 0.952436 (0.026758) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 16}
# 0.930902 (0.034235) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 8, 'units2': 32}
# 0.948274 (0.000314) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 4}
# 0.956932 (0.012090) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 8}
# 0.952547 (0.012364) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 16}
# 0.948163 (0.028158) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 16, 'units2': 32}
# 0.943889 (0.034172) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 4}
# 0.939671 (0.005936) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 8}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 16}
# 0.965423 (0.016272) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 32, 'units2': 32}
# 0.952547 (0.022140) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 4}
# 0.956876 (0.006243) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 8}
# 0.961205 (0.000235) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 16}
# 0.948218 (0.010808) with: {'batch_size': 32, 'epochs': 100, 'optimizer': 'Nadam', 'units1': 64, 'units2': 32}
