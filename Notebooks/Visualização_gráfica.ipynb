# %% [markdown]
# ---
# ---
# # Visualização gráfica de dados
#
# Este notebook apresenta alguns tipos de gráficos para visualização de dados utilizando as bibliotecas [Matplotlib](https://matplotlib.org/) e/ou [Seaborn](https://seaborn.pydata.org/).
#
# Recomenda-se acessar as galerias de exemplos das duas bibliotecas:
#
# *   https://matplotlib.org/stable/gallery/index.html
# *   https://seaborn.pydata.org/examples/index.html
#
#
#
# ---
# ---

# %% [markdown]
# ## Clona repositório de dados da disciplina hospedado no GitHUb

# %%
# !git clone "https://github.com/malegopc/DSBD"
# Out:
# Cloning into 'DSBD'...
# remote: Enumerating objects: 158, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (139/139), done.
# remote: Total 158 (delta 43), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (158/158), 3.56 MiB | 4.29 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %% [markdown]
# ## Importação das bibliotecas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
#
#
# ##Gráficos de linha
#
#
# ---

# %%
import numpy as np
x = np.linspace(-5, 5)
y = x ** 2
plt.plot(x, y, 'r') # 'r' é a cor vermelha (red)
plt.xlabel('Eixo x')
plt.ylabel('Eixo x')
plt.title('y = x^2')
plt.show()

# %% [markdown]
# ####Subplots (vários plots na mesma tela)

# %%
plt.subplot(2,2,1) # 2x2
plt.plot(x, y, 'r--') 
plt.subplot(2,2,2)
plt.plot(y, x, 'g*-');
plt.subplot(2,2,3)
plt.plot(x, y, 'b+-');
plt.subplot(2,2,4)
plt.plot(y, x, 'k^-');

# %% [markdown]
# Outra maneira de plotar vários gráficos (subplots):

# %%
fig, axes = plt.subplots(1, 2, figsize=(10,3))

# Aparência padrão 
axes[0].plot(x, y)
axes[0].grid(True)

# Aparência customizada 
axes[1].plot(x, y, x, x**3, lw=4)
axes[1].grid(color='k', alpha=0.5, linestyle='dashed', lw=2)

# %% [markdown]
# Salvando a figura em arquivo:

# %%
fig.savefig("graflines.png")

# %% [markdown]
# ####Outro exemplo de gráfico de linha:
#
# Preços das ações da PETR4 lidos a partir de um arquivo csv.

# %%
import pandas as pd
# lê arquivo de dados
df = pd.read_csv('/content/DSBD/Datasets/Ações_Petro/PETR4_train.csv')
df = df.dropna() # elimina linhas null
# mostra os dados
df
# Out:
#             Date       Open   High        Low      Close  Adj Close      Volume
# 0     2015-01-02   9.990000   9.99   9.350000   9.360000   8.683293  49559500.0
# 1     2015-01-05   9.140000   9.19   8.530000   8.560000   7.941135  78385100.0
# 2     2015-01-06   8.710000   8.83   8.040000   8.280000   7.681378  84723300.0
# 3     2015-01-07   8.560000   8.73   8.360000   8.670000   8.043181  85531000.0
# 4     2015-01-08   8.790000   9.39   8.740000   9.230000   8.562695  83306300.0
# ...          ...        ...    ...        ...        ...        ...         ...
# 1237  2019-12-19  30.450001  30.75  30.420000  30.610001  30.189920  39696000.0
# 1238  2019-12-20  30.600000  30.60  30.020000  30.260000  29.844723  93064900.0
# 1239  2019-12-23  30.190001  30.50  30.030001  30.500000  30.081429  21970200.0
# 1240  2019-12-26  30.590000  30.93  30.500000  30.910000  30.485802  24810500.0
# 1241  2019-12-27  30.690001  30.92  30.290001  30.520000  30.517742  24995100.0
#
# ...

# %%
open = df.iloc[:, 1:2].values # pega os valores da coluna 1 (open)
plt.figure(figsize=(15,5))
plt.subplot(1, 2, 1)
plt.title("Preço das ações da PETR4")
plt.plot(open)
plt.grid(True)

# %% [markdown]
# ---
#
#
# ##Gráficos de barras/colunas
#
#
# ---

# %% [markdown]
# Usando Matplotlib:

# %%
values = [12, 55, 4, 32, 14]
colors = ['r', 'g', 'b', 'c', 'm']
#plt.bar(range(0,5), values, color= colors)
plt.barh(range(0,5), values, color= colors)
plt.show()

# %% [markdown]
# Outro exemplo usando Seaborn:

# %%
#sns.set_theme(style="whitegrid")
tips = sns.load_dataset("tips") # conjunto de dados "tips" (gorjetas) do Seaborn
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# ####Gráfico de barras agrupadas usando Matplotlib

# %%
sns.barplot(x = 'sex',y = 'tip',hue = 'day',data = tips, palette = "Reds")
plt.title('Título do gráfico')
plt.xlabel('Sex')
plt.ylabel('Tips') 
plt.show()

# %% [markdown]
# ---
#
#
# ##Histogramas
#
#
# ---

# %% [markdown]
# Usando Matplotlib

# %%
from random import sample
dados = sample(range(1, 1000), 100)
plt.hist(dados)
plt.show()

# %%
plt.subplot(2,2,1) # 2x2
plt.hist(tips['sex']) 
plt.subplot(2,2,2)
plt.hist(tips['smoker']) 
plt.subplot(2,2,3)
plt.hist(tips['day']) 
plt.subplot(2,2,4)
plt.hist(tips['time']) 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# Usando Seaborn

# %%
penguins = sns.load_dataset("penguins") # base de dados 
sns.histplot(data=penguins, x="flipper_length_mm", kde=True)

# %% [markdown]
# Com distribuições múltiplas e empilhadas

# %%
sns.histplot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack")

# %% [markdown]
# ---
#
#
# ##Gráficos de setores
#
#
# ---

# %%
#Criando o conjunto de dados
cars = ['AUDI', 'BMW', 'NISSAN','TESLA', 'HYUNDAI', 'HONDA'] 
data = [20, 12, 15, 5, 16, 30] 
plt.pie(data, labels = cars)
plt.title('Mercado de carros')
plt.show()

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.2, 0, 0.1)  # destaca Hogs e Logs

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', 
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.show()

# %% [markdown]
# ---
#
#
# ##Boxplots
#
#
# ---

# %% [markdown]
# Utilizando Matplotlib

# %%
uniformSkewed = np.random.rand(100) * 100 - 40
high_outliers = np.random.rand(10) * 50 + 100
low_outliers = np.random.rand(10) * -50 - 100
data = np.concatenate((uniformSkewed, high_outliers, low_outliers))
plt.boxplot(data)
plt.show()

# %% [markdown]
# Utilizando Seaborn

# %%
sns.boxplot(x=tips['tip']);

# %% [markdown]
# Boxplots agrupados

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True) # remove bordas

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# box plot retangular
plt.boxplot(data,vert=True,patch_artist=True);

# %%
df = pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")
sns.set(rc={'figure.figsize':(15,5)})
ax=sns.boxplot(x='Mfr Name', y='CombMPG', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ---
#
# ##Outros tipos e exemplos de visualização de dados (gráficos)
#
#
# ---

# %% [markdown]
# ### Gráfico de "enxame"
# Outra forma de visualizar os mesmos dados do exemplo anterior é o "gráfico de enxame". Em vez de caixas (boxs), ele plota cada ponto de dados individualmente, mas os agrupa com base em sua distribuição.

# %%
#ax=sns.swarmplot(x='Mfr Name', y='CombMPG', data=df)
ax=sns.stripplot(x='Mfr Name', y='CombMPG', data=df)
sns.set(rc={'figure.figsize':(20,5)})
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show()

# %% [markdown]
# ###Countplot (gráfico de contagem = "histograma")
#
# Outra ferramenta é o "gráfico de contagem". É basicamente a mesma coisa que um histograma, mas para dados categóricos. Ele permite que você conte quantas vezes cada categoria no eixo X ocorre em seus dados e plote-os.

# %%
ax=sns.countplot(x='Mfr Name', data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
plt.show()

# %% [markdown]
# ###Scatter (dispersão), step e fill_between

# %%
n = np.array([0,1,2,3,4,5])
xx = np.linspace(-0.75, 1., 100)
fig, axes = plt.subplots(1, 3, figsize=(12,3))

axes[0].scatter(xx, xx + 0.25*np.random.randn(len(xx)))
axes[0].set_title("scatter")

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[2].set_title("fill_between");

# %% [markdown]
# ###Gráficos de superfícies
#
# Para usar gráficos 3D no matplotlib, basta criar uma instância da classe Axes3D. Os eixos 3D podem ser adicionados a uma tela matplotlib exatamente da mesma maneira que os eixos 2D; ou passando um argumento de palavra-chave projection = '3d' para os métodos add_axes ou add_subplot.

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

fig = plt.figure(figsize=(14,6))

# ax é uma instância de eixo com reconhecimento 3D 
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot com classificação de cores e barra de cores
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# #### Superfície de contorno com projeções nos planos

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=plt.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)
# <function matplotlib.pyplot.show>

# %% [markdown]
# ###Mapas geográficos
#
# https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.13-Geographic-Data-With-Basemap.ipynb
